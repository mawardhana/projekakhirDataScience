# %%
# !pip install google-play-scraper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: google-play-scraper in /usr/local/lib/python3.7/dist-packages (1.2.2)

# %%
from google_play_scraper import app
import pandas as pd #untukmembuatdataframe
import numpy as np #untukoperasivektroataumatriks

# %%
from google_play_scraper import Sort, reviews_all
us_reviews = reviews_all(
    'com.bibit.bibitid',
    sleep_milliseconds=0, # defaults to 0
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT
    count=250,
)

# %%
df_data = pd.DataFrame(np.array(us_reviews),columns=['review'])
df_data = df_data.join(pd.DataFrame(df_data.pop('review').tolist()))
df_data.head()
# Out:
#                                reviewId           userName  \
# 0  e43bc637-dbbf-48a5-abb4-ee2d8dc7aeb9     Ismail Mahmudi
# 1  f71bca1c-7cd5-4ff6-b6d3-d2e498c4ab10      Erik Setiawan
# 2  aae59e39-7a82-4532-bfaa-baaafa3c29be  Tegy Andika Akbar
# 3  fc4e4352-9748-4e81-9db2-45e1104bd431      Ikhsan Ananda
# 4  4961a97f-2f81-43cb-9049-a4dbb7116d56        Nabilah Kim
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ACNPE...
# 1  https://play-lh.googleusercontent.com/a-/ACNPE...
# 2  https://play-lh.googleusercontent.com/a/ALm5wu...
# 3  https://play-lh.googleusercontent.com/a/ALm5wu...
# 4  https://play-lh.googleusercontent.com/a-/ACNPE...
#
#                                              content  score  thumbsUpCount  \
# 0            sangat mudah sekali untuk ber investasi      5              0
# 1  Sangat terbantu dengan bibit apalagi terhubung...      5              0
# 2                                               good      5              0
# 3  pelayanan nya bagus sekali, sukses trus bibit ...      5              0
# 4  Baru pake apl ini Tapi loading nya lama banget...      1              0
#
#   reviewCreatedVersion                  at  \
# 0               3.43.0 2022-11-18 05:48:25
# 1               3.44.0 2022-11-18 05:31:17
# 2               3.44.0 2022-11-18 05:23:16
# 3               3.44.0 2022-11-18 04:08:16
# 4               3.44.0 2022-11-18 02:23:50
#
#                                         replyContent           repliedAt
# 0                                               None                 NaT
# 1                                               None                 NaT
# 2                                               None                 NaT
# 3                                               None                 NaT
# 4  Hai kak, kemungkinan jaringan internet kakak t... 2022-11-18 04:14:22

# %%
len(df_data.index)
# Out:
# 40992

# %%
df_data[['userName', 'score','at', 'content']].head()
# Out:
#             userName  score                  at  \
# 0     Ismail Mahmudi      5 2022-11-18 05:48:25
# 1      Erik Setiawan      5 2022-11-18 05:31:17
# 2  Tegy Andika Akbar      5 2022-11-18 05:23:16
# 3      Ikhsan Ananda      5 2022-11-18 04:08:16
# 4        Nabilah Kim      1 2022-11-18 02:23:50
#
#                                              content
# 0            sangat mudah sekali untuk ber investasi
# 1  Sangat terbantu dengan bibit apalagi terhubung...
# 2                                               good
# 3  pelayanan nya bagus sekali, sukses trus bibit ...
# 4  Baru pake apl ini Tapi loading nya lama banget...

# %%
review = df_data[['userName', 'score','at', 'content']]
sorted_df = review.sort_values(by='at', ascending=False) 
sorted_df.head()
# Out:
#             userName  score                  at  \
# 0     Ismail Mahmudi      5 2022-11-18 05:48:25
# 1      Erik Setiawan      5 2022-11-18 05:31:17
# 2  Tegy Andika Akbar      5 2022-11-18 05:23:16
# 3      Ikhsan Ananda      5 2022-11-18 04:08:16
# 4        Nabilah Kim      1 2022-11-18 02:23:50
#
#                                              content
# 0            sangat mudah sekali untuk ber investasi
# 1  Sangat terbantu dengan bibit apalagi terhubung...
# 2                                               good
# 3  pelayanan nya bagus sekali, sukses trus bibit ...
# 4  Baru pake apl ini Tapi loading nya lama banget...

# %%
ss = sorted_df[['userName', 'score','at', 'content']]

# %%
ss.head()
# Out:
#             userName  score                  at  \
# 0     Ismail Mahmudi      5 2022-11-18 05:48:25
# 1      Erik Setiawan      5 2022-11-18 05:31:17
# 2  Tegy Andika Akbar      5 2022-11-18 05:23:16
# 3      Ikhsan Ananda      5 2022-11-18 04:08:16
# 4        Nabilah Kim      1 2022-11-18 02:23:50
#
#                                              content
# 0            sangat mudah sekali untuk ber investasi
# 1  Sangat terbantu dengan bibit apalagi terhubung...
# 2                                               good
# 3  pelayanan nya bagus sekali, sukses trus bibit ...
# 4  Baru pake apl ini Tapi loading nya lama banget...

# %%
ss.to_csv("ReviewBibit.csv", index = False)
